# %%
# %pip install numpy==1.26.4 pyyaml==6.0.1 jsonschema==4.21.1 --quiet

# %%
import numpy as np, yaml, jsonschema 
print(f"numpy: {np.__version__}") 
print(f"pyyaml: {yaml.__version__}") 
print(f"jsonschema: {jsonschema.__version__}") 
print("All OK")
